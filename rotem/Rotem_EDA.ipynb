# %%
path = 'c:\\Users\\jaeju\\vscode\\Onepredict\\rotem\\Data\\Kairo_race_data\\kairo.xlsx'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd

df = pd.read_excel(path, engine = 'openpyxl')

df
# Out:
#                          Time  TrainID  Powering  Braking  Train Speed  \
# 0     2024-04-24 19:53:30.000        3         0        0          0.0
# 1     2024-04-24 19:53:31.000        3         0        0          0.0
# 2     2024-04-24 19:53:32.000        3         0        0          0.0
# 3     2024-04-24 19:53:33.000        3         0        0          0.0
# 4     2024-04-24 19:53:34.000        3         0        0          0.0
# ...                       ...      ...       ...      ...          ...
# 8319  2024-04-24 22:20:21.000        3         0        0          0.0
# 8320  2024-04-24 22:20:22.000        3         0        0          0.0
# 8321  2024-04-24 22:20:23.000        3         0        0          0.0
# 8322  2024-04-24 22:20:24.000        3         0        0          0.0
# 8323  2024-04-24 22:20:25.000        3         0        0          0.0
#
#       Line Voltage  Motor Current \n(Car 1 Inverter Unit 1)  Distance  \
# 0           1515.6                                        0         0
# 1           1511.7                                        0         0
# 2           1507.8                                        0         0
# 3           1525.3                                        0         0
# 4           1523.4                                        0         0
# ...            ...                                      ...       ...
# 8319        1626.9                                        0         0
# 8320        1636.7                                        0         0
# 8321        1601.5                                        0         0
# 8322        1613.2                                        0         0
# 8323        1638.6                                        0         0
#
#       Next Station
# 0               10
# 1               10
# 2               10
# 3               10
# 4               10
# ...            ...
# 8319             1
# 8320             1
# 8321             1
# 8322             1
# 8323             1
#
# [8324 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8324 entries, 0 to 8323
# Data columns (total 9 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Time                                    8324 non-null   object
#  1   TrainID                                 8324 non-null   int64
#  2   Powering                                8324 non-null   int64
#  3   Braking                                 8324 non-null   int64
#  4   Train Speed                             8324 non-null   float64
#  5   Line Voltage                            8324 non-null   float64
#  6   Motor Current
# (Car 1 Inverter Unit 1)  8324 non-null   int64
#  7   Distance                                8324 non-null   int64
#  8   Next Station                            8324 non-null   int64
# dtypes: float64(2), int64(6), object(1)
# memory usage: 585.4+ KB

# %%
df.columns
# Out:
# Index(['Time', 'TrainID', 'Powering', 'Braking', 'Train Speed', 'Line Voltage',
#        'Motor Current \n(Car 1 Inverter Unit 1)', 'Distance', 'Next Station'],
#       dtype='object')

# %%
numeric_columns = df.select_dtypes(include=['int64', 'float64']).columns
numeric_columns
# Out:
# Index(['TrainID', 'Powering', 'Braking', 'Train Speed', 'Line Voltage',
#        'Motor Current \n(Car 1 Inverter Unit 1)', 'Distance', 'Next Station'],
#       dtype='object')

# %%
for cols in numeric_columns:
    print(f'{cols} unique 값 : {df[cols].nunique()}')
# Out:
# TrainID unique 값 : 1
# Powering unique 값 : 71
# Braking unique 값 : 69
# Train Speed unique 값 : 4082
# Line Voltage unique 값 : 208
# Motor Current
# (Car 1 Inverter Unit 1) unique 값 : 256
# Distance unique 값 : 99
# Next Station unique 값 : 35

# %%
'''
numeric 변수들을 시각화 찍어봤다
'''
for column in numeric_columns:
    plt.figure(figsize=(8, 4))
    df[column].hist(bins=10, alpha=0.7, color='blue')
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.grid(False)
    plt.show()
